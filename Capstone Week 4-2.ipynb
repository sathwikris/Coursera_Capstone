# %% [markdown]
# # The Battle of Neighborhoods

# %% [markdown]
# ### Data Details

# %% [markdown]
# ##### We will need data about different venues in different neighborhoods of that specific Scarborough which we got in Week 3 from Wikipedia . For that purpose we will employ Foursquare. All the relevant detailes can be found at Foursquare.
#
# #### The data retrieved from Foursquare contained information of venues within a specified distance of the longitude and latitude of the postcodes. The information obtained per venue as follows:
#
# ###### 1. Neighborhood
# ###### 2. Neighborhood Latitude
# ###### 3. Neighborhood Longitude
# ###### 4. Venue
# 5. Name of the venue e.g. the name of a store or restaurant
# 6. Venue Latitude
# 7. Venue Longitude
# 8. Venue Category
