# %% [markdown]
# # The Battle of Neighborhoods

# %% [markdown]
# ## Introduction:

# %% [markdown]
# #### The main objective of this task is to help people finding better facilities around their neighborhood easy and fast. Here, We shall take the example of the city of Toronto. This will be helpful for new people who are looking for better schools, shops, restraunts, parks, gyms, etc. As we used in one of the previous examples, here we shall use Scarboroughas the target. The features include median housing price and better school according to ratings, crime rates of that particular area, road connectivity, weather conditions, good management for emergency, water resources both freash and waste water and excrement conveyed in sewers and recreational facilities.

# %% [markdown]
# #### The major purpose of this project, is to suggest a better neighborhood in a new city for the person who who i new to it. Social presence in society in terms of like minded people. Connectivity to the airport, bus stand, city center, markets and other daily needs things nearby.
# #### Sorted list of house in terms of housing prices in a ascending or descending order
# #### Sorted list of schools in terms of location, fees, rating and reviews

# %% [markdown]
# #### Scarborough is a popular destination for new immigrants in Canada to reside. As a result, it is one of the most diverse and multicultural areas in the Greater Toronto Area, being home to various religious groups and places of worship. Although immigration has become a hot topic over the past few years with more governments seeking more restrictions on immigrants and refugees, the general trend of immigration into Canada has been one of on the rise.

# %% [markdown]
# ### We will use Foursquare API along with clustering (k-means). Below are the required libraries

# %% [markdown]
# ##### Pandas, Scikit, XML, JSON, Matplotlib, Geocoder, Folium and Beautiful Soup
